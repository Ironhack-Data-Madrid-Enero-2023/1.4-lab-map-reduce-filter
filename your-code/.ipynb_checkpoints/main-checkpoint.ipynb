# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# import reduce from functools, numpy and pandas
from functools import reduce
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up a words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
new_prophet = prophet[568:]

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
print(prophet[:11])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'EBook', 'of', 'The', 'Prophet,', 'by', 'Kahlil', 'Gibran\n\nThis', 'eBook']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    
    if "{" in x:
        return x.split("{")[0]
    else:
        return x

reference(lista)
# Out:
# 'hola'

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`

# %%
prophet_reference = list(map(reference, new_prophet))

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(a):

    return a.split("\n")

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
prophet_line = line_break(prophet_reference)

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
prophet_flat = [x for x in prophet_line]        
print(prophet_flat)
# Out:
# ['PROPHET', '', '|Almustafa,', 'the', 'chosen', 'and', 'the', 'beloved,', 'who', 'was', 'a', 'dawn', 'unto', 'his', 'own', 'day,', 'had', 'waited', 'twelve', 'years', 'in', 'the', 'city', 'of', 'Orphalese', 'for', 'his', 'ship', 'that', 'was', 'to', 'return', 'and', 'bear', 'him', 'back', 'to', 'the', 'isle', 'of', 'his', 'birth.', '', 'And', 'in', 'the', 'twelfth', 'year,', 'on', 'the', 'seventh', 'day', 'of', 'Ielool,', 'the', 'month', 'of', 'reaping,', 'he', 'climbed', 'the', 'hill', 'without', 'the', 'city', 'walls', 'and', 'looked', 'seaward;', 'and', 'he', 'beheld', 'his', 'ship', 'coming', 'with', 'the', 'mist.', '', 'Then', 'the', 'gates', 'of', 'his', 'heart', 'were', 'flung', 'open,', 'and', 'his', 'joy', 'flew', 'far', 'over', 'the', 'sea.', 'And', 'he', 'closed', 'his', 'eyes', 'and', 'prayed', 'in', 'the', 'silences', 'of', 'his', 'soul.', '', '*****', '', 'But', 'as', 'he', 'descended', 'the', 'hill,', 'a', 'sadness', 'came', 'upon', 'him,', 'and', 'he', 'thought', 'in', 'his', 'heart:', '', 'How', 'shall', 'I', 'go', 'in', 'peace', 'and', 'without', 'sorrow?', 'Nay,', 'not', 'without', 'a', 'wound', 'in', 'the', 'spirit', 'shall', 'I', 'leave', 'this', 'city.', '', 'the', 'days', 'of', 'pain', 'I', 'have', 'spent', 'within', 'its', 'walls,', 'and', 'long', 'were', 'the', 'nights', 'of', 'aloneness;', 'and', 'who', 'can', 'depart', 'from', 'his', 'pain', 'and', 'his', 'aloneness', 'without', 'regret?', '', 'Too', 'many', 'fragments', 'of', 'the', 'spirit', 'have', 'I', 'scattered', 'in', 'these', 'streets,', 'and', 'too', 'many', 'are', 'the', 'children', 'of', 'my', 'longing', 'that', 'walk', 'naked', 'among', 'these', 'hills,', 'and', 'I', 'cannot', 'withdraw', 'from', 'them', 'without', 'a', 'burden', 'and', 'an', 'ache.', '', 'It', 'is', 'not', 'a', 'garment', 'I', 'cast', 'off', 'this', 'day,', 'but', 'a', 'skin', 'that', 'I', 'tear', 'with', 'my', 'own', 'hands.', '', 'Nor', 'is', 'it', 'a', 'thought', 'I', 'leave', 'behind', 'me,', 'but', 'a', 'heart', 'made', 'sweet', 'with', 'hunger', 'and', 'with', 'thirst.', '', '*****', '', 'Yet', 'I', 'cannot', 'tarry', 'longer.', '', 'The', 'sea', 'that', 'calls', 'all', 'things', 'unto', 'her', 'calls', 'me,', 'and', 'I', 'must', 'embark.', '', 'For', 'to', 'stay,', 'though', 'the', 'hours', 'burn', 'in', 'the', 'night,', 'is', 'to', 'freeze', 'and', 'crystallize', 'and', 'be', 'bound', 'in', 'a', 'mould.', '', 'Fain', 'would', 'I', 'take', 'with', 'me', 'all', 'that', 'is', 'here.', 'But', 'how', 'shall', 'I?', '', 'A', 'voice', 'cannot', 'carry', 'the', 'tongue', 'and', '', 'lips', 'that', 'gave', 'it', 'wings.', 'Alone', 'must', 'it', 'seek', 'the', 'ether.', '', 'And', 'alone', 'and', 'without', 'his', 'nest', 'shall', 'the', 'eagle', 'fly', 'across', 'the', 'sun.', '', '*****', '', 'Now', 'when', 'he', 'reached', 'the', 'foot', 'of', 'the', 'hill,', 'he', 'turned', 'again', 'towards', 'the', 'sea,', 'and', 'he', 'saw', 'his', 'ship', 'approaching', 'the', 'harbour,', 'and', 'upon', 'her', 'prow', 'the', 'mariners,', 'the', 'men', 'of', 'his', 'own', 'land.', '', 'And', 'his', 'soul', 'cried', 'out', 'to', 'them,', 'and', 'he', 'said:', '', 'Sons', 'of', 'my', 'ancient', 'mother,', 'you', 'riders', 'of', 'the', 'tides,', '', 'How', 'often', 'have', 'you', 'sailed', 'in', 'my', 'dreams.', 'And', 'now', 'you', 'come', 'in', 'my', 'awakening,', 'which', 'is', 'my', 'deeper', 'dream.', '', 'Ready', 'am', 'I', 'to', 'go,', 'and', 'my', 'eagerness', 'with', 'sails', 'full', 'set', 'awaits', 'the', 'wind.', '', 'Only', 'another', 'breath', 'will', 'I', 'breathe', 'in', 'this', 'still', 'air,', 'only', 'another', 'loving', 'look', 'cast', 'backward,', '', 'And', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'a', 'seafarer', 'among', 'seafarers.', '', 'you,', 'vast', 'sea,', 'sleepless', 'mother,', '', 'Who', 'alone', 'are', 'peace', 'and', 'freedom', 'to', 'the', 'river', 'and', 'the', 'stream,', '', 'Only', 'another', 'winding', 'will', 'this', 'stream', 'make,', 'o ...

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(a):
    word_list = ['and', 'the', 'a', 'an']
    for x in a:
        if x in word_list:
            return False
    return True

    
word_filter(["a", "ol"])
# Out:
# False

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
prophet_filter = filter(word_filter, prophet_flat)

# %% [markdown]
# # Bonus Challenge - Part 1
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(a):
   
    word_list = ['and', 'the', 'a', 'an']
    for x in a:
        if x.lower() in word_list.lower():
            return True
    return False
    # Your code here:

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def cooncat_space(a, b):
    return a + " "  + b

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
prophet_string = reduce(cooncat_space, prophet_filter)

print(prophet_string)
# Out:
# PROPHET  the chosen the beloved, who unto his own twelve in the city of for his ship to return him to the isle of his birth.  And in the twelfth on the seventh of Ielool, the month of he climbed the hill without the city looked he beheld his ship coming with the mist.  Then the of his were flung open, his joy flew over the And he closed his eyes in the silences of his soul.  *****  But he descended the hill, upon him, he thought in his  How I go in without sorrow? not without wound in the spirit I this city.  the of I spent within its long were the nights of who from his his without regret?  Too of the spirit I in these streets, too the children of my longing these hills, I from them without burden  It is not I off this but skin I with my own  Nor is it thought I behind me, but sweet with hunger with thirst.  *****  Yet I longer.  The things unto her me, I must  For to though the hours burn in the night, is to freeze be bound in mould.  would I with me is here. But how I?  A voice the tongue  lips it wings. Alone must it seek the ether.  And without his nest the fly the sun.  *****  Now when he the foot of the hill, he turned the he his ship the upon her prow the the men of his own  And his soul cried out to them, he  Sons of my mother, you riders of the tides,  How often you in my And now you come in my which is my deeper  I to go, my with full set the wind.  Only will I in this still only loving look  And then I you,  you, sleepless mother,  Who freedom to the river the  Only winding will this only murmur in this  And then I come to you, boundless drop to boundless  *****  And he he from men women their fields their the city  And he their voices his shouting from field to field telling one of the coming of his ship.  And he to himself:  the of be the of  And it be my eve in truth my  And I give unto him who left his plough in midfurrow, or to him who stopped the wheel of his winepress?  my become tree with fruit I give unto them?  And my desires flow like I fill their cups?  Am I the of the mighty touch me, or flute his through me?  A seeker of silences I, I found in silences I dispense with confidence?  If this is my of in fields I sowed the seed, in unremembered  If this indeed be the hour in which I lift up my it is not my burn therein.  Empty I my  And the of the night fill it with oil he light it  *****  These things he in words. But much in his For  could not his deeper secret.  *****  0020]  And when he entered into the city the people to meet him, they were crying out to him with one voice.  And the elders of the city stood forth  Go not yet from us.  A noontide you been in our twilight, your youth given us to  No you us, nor guest, but our son our beloved.  Suffer not yet our eyes to hunger for your  *****  And the priests the priestesses unto him:  Let not the of the us now, the you spent in our midst become memory.  You us spirit,  your been light upon our  Much we loved you. But speechless our love, with veils it been veiled.  Yet now it cries unto you, would before you.  And ever it been love knows not its own depth until the hour of  *****  And others him. But he them not. He only bent his those who stood his upon his  And he the people proceeded the before the temple.  And there out of the whose And she seeress.  And he looked upon her with exceeding tenderness, for it she who first sought believed in him when he been but in their city.  him,  Prophet of God, in quest of the uttermost, long you the for your ship.  And now your ship come, you must needs go.  Deep is your longing for the of your memories the dwelling of your desires; our love would not bind you nor our needs hold you.  Yet this we ere you us, you to us give us of your truth.  And we will give it unto our children, they unto their children, it not perish.  In your you with our in your you listened to the weeping the of our sleep.  Now therefore disclose us to ourselves, tell us been shown you of which is between birth  *****  And he  People of of ...

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will load a dataset below and then write a function that will perform the transformation.

# %%
# Run this code:

# The dataset below contains information about pollution from PM2.5 particles in Beijing 

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"
pm25 = pd.read_csv(url)

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# Your code here:

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''
    
    # Your code here:

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
# Your code here:

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # Your code here:
